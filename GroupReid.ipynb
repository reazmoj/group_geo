# %%
# Install conda
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:10
# 🔁 Restarting kernel...

# %%
# !conda install -c conda-forge mamba -y
# Out:
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mamba
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     archspec-0.2.3             |     pyhd8ed1ab_0          48 KB  conda-forge
#     ca-certificates-2024.8.30  |       hbcca054_0         155 KB  conda-forge
#     certifi-2024.8.30          |     pyhd8ed1ab_0         160 KB  conda-forge
#     conda-24.7.1               |  py310hff52083_0         940 KB  conda-forge
#     fmt-10.2.1                 |       h00ab1b0_0         189 KB  conda-forge
#     frozendict-2.4.6           |  py310ha75aee5_0          48 KB  conda-forge
#     libcurl-8.8.0              |       hca28451_0         396 KB  conda-forge
#     libgcc-14.2.0              |       h77fa898_1         829 KB  conda-forge
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# drive.flush_and_unmount()
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/daodaofr/group_reid.git

# %%
# %cd /content/drive/MyDrive/project/group_reid/
# Out:
# /content/drive/MyDrive/project/group_reid

# %%
# !mamba env create -f env.yml
# Out:
# Channels:
#  - defaults
#  - conda-forge
#  - pytorch
#  - nvidia
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.7.1
#     latest version: 24.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# python-3.7.16        | 44.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# libstdcxx-ng-11.2.0  | 4.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# openssl-1.1.1w       | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# tk-8.6.14            | 3.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# pip-22.3.1           | 2.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# sqlite-3.45.3        | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# setuptools-65.6.3    | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# ncurses-6.4          | 914 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ...

# %%
import pickle

# Load the pickle file with the correct encoding
with open('/content/drive/MyDrive/project/group_reid/data/building_dataset1.pkl', 'rb') as f:
    res = pickle.load(f, encoding='latin1')  # Specify 'latin1' encoding to handle non-ASCII characters

# %%
# res

# %%
# !unzip /content/drive/MyDrive/dataset/CUHK-SYSU.zip -d /content/drive/MyDrive/project/group_reid/data

# %%
# !source activate gprr && python main_group_gcn_siamese_part_half_fulltest_sink.py --data-root /content/drive/MyDrive/project/group_reid/data/Building/images  --max-epoch 100 --stepsize 100 --eval-step 300 --gpu-devices 0
# Out:
# ...
# Args:Namespace(arch='resnet50gcn_siamese_part_half_sink', data_root='/content/drive/MyDrive/project/group_reid/data/Building/images', dataset='cuhk-group', eval_step=300, evaluate=False, gallery_batch=16, gamma=0.1, gpu_devices='0', height=224, htri_only=False, lr=0.0003, margin=0.3, max_epoch=100, num_instances=2, pool='avg', pretrained_model='', print_freq=100, save_dir='log1', seed=1, start_epoch=0, stepsize=100, test_batch=1, train_batch=8, use_cpu=False, warmup=False, weight_decay=0.0005, width=224, workers=4, xent_only=False)
# ...
# Currently using GPU 0
# ...

# %%
# !source activate gprr && python main_group_gcn_siamese_part_half_fulltest_sink.py --data-root /content/drive/MyDrive/project/group_reid/data/Building/images  --gpu-devices 0 --evaluate True
# Out:
# ...
# Args:Namespace(arch='resnet50gcn_siamese_part_half_sink', data_root='/content/drive/MyDrive/project/group_reid/data/Building/images', dataset='cuhk-group', eval_step=200, evaluate=True, gallery_batch=16, gamma=0.1, gpu_devices='0', height=224, htri_only=False, lr=0.0003, margin=0.3, max_epoch=200, num_instances=2, pool='avg', pretrained_model='', print_freq=100, save_dir='log1', seed=1, start_epoch=0, stepsize=70, test_batch=1, train_batch=8, use_cpu=False, warmup=False, weight_decay=0.0005, width=224, workers=4, xent_only=False)
# ...
# Currently using GPU 0
# ...
